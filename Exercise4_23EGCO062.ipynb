# %% [markdown]
# <a href="https://colab.research.google.com/github/imeekong/Tryouts/blob/main/Exercise4_23EGCO062.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NAME: Ime Ime Ekong
#
# REGISTRATION NUMBER: 23/EG/CO/062

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv('/content/Smartphones_dataset.csv')
df =pd.read_csv('/content/wearable_health_devices_performance_upto_26june2025.csv')

# %% [markdown]
# DATASET OVERVIEW

# %% [markdown]
# 1. What are the Test_Date, Device_Name, Brand, Category, Price_USD, and User_Satisfaction_Rating for the first four samples in the dataset?

# %%
display(df[['Test_Date', 'Device_Name', 'Brand', 'Category', 'Price_USD', 'User_Satisfaction_Rating']].head(4))
# Out:
#     Test_Date       Device_Name   Brand         Category  Price_USD  \
# 0  2025-06-01  Fitbit Inspire 4  Fitbit  Fitness Tracker     141.74
# 1  2025-06-01  Apple Watch SE 3   Apple       Smartwatch     834.64
# 2  2025-06-01    Fitbit Versa 4  Fitbit     Sports Watch     145.34
# 3  2025-06-01  Polar Vantage V3   Polar       Smartwatch     349.53
#
#    User_Satisfaction_Rating
# 0                       6.5
# 1                       8.3
# 2                       6.0
# 3                       8.0

# %% [markdown]
# 2. What are the Test_Date, Device_Name, Brand, Category, Price_USD, and User_Satisfaction_Rating for the last four samples in the dataset?

# %%
display(df[['Test_Date', 'Device_Name', 'Brand', 'Category', 'Price_USD', 'User_Satisfaction_Rating']].tail(4))
# Out:
#        Test_Date          Device_Name    Brand         Category  Price_USD  \
# 2371  2025-06-25      Fitbit Charge 6   Fitbit  Fitness Tracker     156.48
# 2372  2025-06-25     Apple Watch SE 3    Apple       Smartwatch     282.45
# 2373  2025-06-25  Apple Watch Ultra 2    Apple       Smartwatch     724.99
# 2374  2025-06-25        Amazfit GTS 4  Amazfit     Sports Watch     198.06
#
#       User_Satisfaction_Rating
# 2371                       6.8
# 2372                       7.3
# 2373                       8.4
# 2374                       6.6

# %% [markdown]
# 3. What are the Test_Date, Device_Name, Brand, Category, Price_USD, and User_Satisfaction_Rating for 4 randomly selected samples, using your registration number as the random state?

# %%
display(df[['Test_Date', 'Device_Name', 'Brand', 'Category', 'Price_USD', 'User_Satisfaction_Rating']].sample(4, random_state=62))
# Out:
#        Test_Date              Device_Name    Brand      Category  Price_USD  \
# 111   2025-06-02  Samsung Galaxy Watch FE  Samsung    Smartwatch     524.96
# 1392  2025-06-15          Amazfit T-Rex 3  Amazfit  Sports Watch     144.14
# 1963  2025-06-21         Apple Watch SE 3    Apple    Smartwatch     766.94
# 1806  2025-06-20          Oura Ring Gen 4     Oura    Smart Ring     494.59
#
#       User_Satisfaction_Rating
# 111                        8.9
# 1392                       6.5
# 1963                       9.3
# 1806                       9.4

# %% [markdown]
# 4. Standardize all column names to have lowercase characters and replace spaces and dashes with underscores. Provide the code used for standardization. What is the total number of samples, columns, and memory usage of the dataset?

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_').str.replace('-', '_')
display(f"Total number of samples: {df.shape[0]}")
display(f"Total number of columns: {df.shape[1]}")
display("Memory usage:")
df.info(memory_usage='deep')
# Out:
# 'Total number of samples: 2375'
# 'Total number of columns: 17'
# 'Memory usage:'
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2375 entries, 0 to 2374
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   test_date                        2375 non-null   object
#  1   device_name                      2375 non-null   object
#  2   brand                            2375 non-null   object
#  3   model                            2375 non-null   object
#  4   category                         2375 non-null   object
#  5   price_usd                        2375 non-null   float64
#  6   battery_life_hours               2375 non-null   float64
#  7   heart_rate_accuracy_percent      2375 non-null   float64
#  8   step_count_accuracy_percent      2375 non-null   float64
#  9   sleep_tracking_accuracy_percent  2375 non-null   float64
# ...

# %% [markdown]
# 5. What is the total number of float64, int64, and object columns in the dataset?

# %%
display(df.dtypes.value_counts())
# Out:
# object     8
# float64    8
# int64      1
# Name: count, dtype: int64

# %% [markdown]
# 6. What single command can you use to produce a summary of all categorical values in the dataset?

# %%
display(df.describe(include='object'))
# Out:
#          test_date      device_name    brand       model    category  \
# count         2375             2375     2375        2375        2375
# unique          25               29       10          29           5
# top     2025-06-21  Oura Ring Gen 4  Samsung  Ring Gen 4  Smartwatch
# freq           121              231      263         231        1230
#
#        water_resistance_rating connectivity_features app_ecosystem_support
# count                     2375                  2375                  2375
# unique                       7                     4                     3
# top                       IPX8             Bluetooth        Cross-platform
# freq                       649                   906                  1305

# %% [markdown]
# 7. Provide the total number of samples(count), number of unique values, top value and frequencynfor the following columns: Test_Date, Device_Name, Brand, Model, Category, Water_Resistant_Rating, Connectivity_Features, and App_Ecosystem_Support.

# %%
display(df[['test_date', 'device_name', 'brand', 'model', 'category', 'water_resistance_rating', 'connectivity_features', 'app_ecosystem_support']].describe())
# Out:
#          test_date      device_name    brand       model    category  \
# count         2375             2375     2375        2375        2375
# unique          25               29       10          29           5
# top     2025-06-21  Oura Ring Gen 4  Samsung  Ring Gen 4  Smartwatch
# freq           121              231      263         231        1230
#
#        water_resistance_rating connectivity_features app_ecosystem_support
# count                     2375                  2375                  2375
# unique                       7                     4                     3
# top                       IPX8             Bluetooth        Cross-platform
# freq                       649                   906                  1305

# %% [markdown]
# 8. List all unique categories in the Category column and their total counts

# %%
display(df['category'].value_counts())
# Out:
# category
# Smartwatch         1230
# Sports Watch        513
# Fitness Band        231
# Smart Ring          231
# Fitness Tracker     170
# Name: count, dtype: int64

# %% [markdown]
# 9. List all unique brands in the Brand column and their total counts

# %%
display(df['brand'].value_counts())
# Out:
# brand
# Samsung     263
# Garmin      262
# Apple       257
# Polar       245
# Fitbit      237
# Amazfit     232
# Oura        231
# WHOOP       231
# Withings    212
# Huawei      205
# Name: count, dtype: int64

# %% [markdown]
# DESCRIPTIVE STATISTICS

# %% [markdown]
# 10. What is the mean of all numerical features (Price_USD, Descriptive Statistics, Descriptive Statistics, Step_Count_Accuracy_Percent, Sleep_Tracking_Accuracy_Percent, GPS_Accuracy_Meters, Health_Sensors_Count, Performance_Score)?

# %%
display(df.mean(numeric_only=True))
# Out:
# price_usd                          359.444484
# battery_life_hours                 160.584463
# heart_rate_accuracy_percent         93.483907
# step_count_accuracy_percent         95.910198
# sleep_tracking_accuracy_percent     78.837516
# user_satisfaction_rating             7.966484
# gps_accuracy_meters                  3.247676
# health_sensors_count                 8.912842
# performance_score                   64.047621
# dtype: float64

# %% [markdown]
# 11. What is the standard deviation of all numerical features in the dataset?

# %%
display(df.std(numeric_only=True))
# Out:
# price_usd                          215.671035
# battery_life_hours                 234.815896
# heart_rate_accuracy_percent          3.172078
# step_count_accuracy_percent          1.665484
# sleep_tracking_accuracy_percent      4.843714
# user_satisfaction_rating             0.831801
# gps_accuracy_meters                  1.022825
# health_sensors_count                 3.559990
# performance_score                    5.109075
# dtype: float64

# %% [markdown]
# 12. What is the minimum value of all numerical features in the dataset?

# %%
display(df.min(numeric_only=True))
# Out:
# price_usd                          30.00
# battery_life_hours                 18.00
# heart_rate_accuracy_percent        85.01
# step_count_accuracy_percent        93.00
# sleep_tracking_accuracy_percent    70.00
# user_satisfaction_rating            6.00
# gps_accuracy_meters                 1.50
# health_sensors_count                2.00
# performance_score                  55.10
# dtype: float64

# %% [markdown]
# 13. What is the maximum value of all numerical features in the dataset?

# %%
display(df.max(numeric_only=True))
# Out:
# price_usd                           989.48
# battery_life_hours                 2118.10
# heart_rate_accuracy_percent          98.00
# step_count_accuracy_percent          99.50
# sleep_tracking_accuracy_percent      91.97
# user_satisfaction_rating              9.50
# gps_accuracy_meters                   5.00
# health_sensors_count                 15.00
# performance_score                    78.30
# dtype: float64

# %% [markdown]
# 14. What is the median value of Price_USD across all samples?

# %%
display(df['price_usd'].median())
# Out:
# 334.37

# %% [markdown]
# 15. What are the 25th and 75th percentiles of Battery_Life_Hours in the dataset?

# %%
display(df['battery_life_hours'].quantile([0.25, 0.75]))
# Out:
# 0.25     46.9
# 0.75    177.4
# Name: battery_life_hours, dtype: float64

# %% [markdown]
# 16. What are the count, mean, standard deviation, minimum, and maximum of Heart_Rate_Accuracy_Percent?

# %%
display(df['heart_rate_accuracy_percent'].describe())
# Out:
# count    2375.000000
# mean       93.483907
# std         3.172078
# min        85.010000
# 25%        92.140000
# 50%        94.070000
# 75%        95.925000
# max        98.000000
# Name: heart_rate_accuracy_percent, dtype: float64

# %% [markdown]
# 17. What are the count, mean, standard deviation, minimum, and maximum of Step_Count_Accuracy_Percent?

# %%
display(df['step_count_accuracy_percent'].describe())
# Out:
# count    2375.000000
# mean       95.910198
# std         1.665484
# min        93.000000
# 25%        94.550000
# 50%        95.950000
# 75%        96.960000
# max        99.500000
# Name: step_count_accuracy_percent, dtype: float64

# %% [markdown]
# 18. What are the count, mean, standard deviation, minimum, and maximum of Sleep_Tracking_Accuracy_Percent?

# %%
display(df['sleep_tracking_accuracy_percent'].describe())
# Out:
# count    2375.000000
# mean       78.837516
# std         4.843714
# min        70.000000
# 25%        75.610000
# 50%        78.300000
# 75%        81.930000
# max        91.970000
# Name: sleep_tracking_accuracy_percent, dtype: float64

# %% [markdown]
# 19. What are the count, mean, standard deviation, minimum, and maximum of Performance_Score?

# %%
display(df['performance_score'].describe())
# Out:
# count    2375.000000
# mean       64.047621
# std         5.109075
# min        55.100000
# 25%        60.400000
# 50%        62.200000
# 75%        67.700000
# max        78.300000
# Name: performance_score, dtype: float64

# %% [markdown]
# CATEGORICAL FEATURE ANALYSIS

# %% [markdown]
# 20. How many unique devices are listed in the Device_Name column?

# %%
display(df['device_name'].nunique())
# Out:
# 29

# %% [markdown]
# 21. How many unique models are listed in the Model column?

# %%
display(df['model'].nunique())
# Out:
# 29

# %% [markdown]
# 22. What is the most frequent Water_Resistance_Rating and its frequency?

# %%
most_frequent_rating = df['water_resistance_rating'].value_counts().idxmax()
frequency = df['water_resistance_rating'].value_counts().max()
display(f"Most frequent Water_Resistance_Rating: {most_frequent_rating}")
display(f"Frequency: {frequency}")
# Out:
# 'Most frequent Water_Resistance_Rating: IPX8'
# 'Frequency: 649'

# %% [markdown]
# 23. What is the most frequent Connectivity_Features values and its frequency?

# %%
most_frequent_connectivity = df['connectivity_features'].value_counts().idxmax()
frequency = df['connectivity_features'].value_counts().max()
display(f"Most frequent Connectivity Features: {most_frequent_connectivity}")
display(f"Frequency: {frequency}")
# Out:
# 'Most frequent Connectivity Features: Bluetooth'
# 'Frequency: 906'

# %% [markdown]
# 24. What is the most frequent App_Ecosystem_Support value and its frequency?

# %%
most_frequent_ecosystem = df['app_ecosystem_support'].value_counts().idxmax()
frequency = df['app_ecosystem_support'].value_counts().max()
display(f"Most frequent App Ecosystem Support: {most_frequent_ecosystem}")
display(f"Frequency: {frequency}")
# Out:
# 'Most frequent App Ecosystem Support: Cross-platform'
# 'Frequency: 1305'

# %% [markdown]
# 25. How many devices have Smartwatch as their Category?

# %%
smartwatch_count = df[df['category'] == 'Smartwatch'].shape[0]
display(f"Number of devices with Smartwatch as their Category: {smartwatch_count}")
# Out:
# 'Number of devices with Smartwatch as their Category: 1230'

# %% [markdown]
# 26. How many devices are from the Fitbit brand?

# %%
fitbit_count = df[df['brand'] == 'Fitbit'].shape[0]
display(f"Number of devices from Fitbit brand: {fitbit_count}")
# Out:
# 'Number of devices from Fitbit brand: 237'

# %% [markdown]
# 27. How many devices support WiFi, Bluetooth, NFC, LTE in the Connectivity_Features column?

# %%
connectivity_counts = {}
for feature in ['WiFi', 'Bluetooth', 'NFC', 'LTE']:
    connectivity_counts[feature] = df['connectivity_features'].str.contains(feature).sum()
for feature, count in connectivity_counts.items():
    display(f"Number of devices supporting {feature}: {count}")
# Out:
# 'Number of devices supporting WiFi: 1469'
# 'Number of devices supporting Bluetooth: 2375'
# 'Number of devices supporting NFC: 1230'
# 'Number of devices supporting LTE: 617'

# %% [markdown]
# 28. List all devices with Cross-platform support in the App_Ecosystem_Support column?

# %%
cross_platform_devices = df[df['app_ecosystem_support'] == 'Cross-platform']['device_name']
display(cross_platform_devices)
# Out:
# 0            Fitbit Inspire 4
# 2              Fitbit Versa 4
# 3            Polar Vantage V3
# 5       Garmin Forerunner 965
# 6        Withings ScanWatch 2
#                 ...
# 2365        Withings Steel HR
# 2366          Garmin Enduro 3
# 2367           Fitbit Sense 2
# 2368     Withings ScanWatch 2
# 2371          Fitbit Charge 6
# Name: device_name, Length: 1305, dtype: object

# %% [markdown]
# 29. What is the distribution of devices across the Test_Date values (count of devices per date)?

# %%
display(df['test_date'].value_counts())
# Out:
# test_date
# 2025-06-21    121
# 2025-06-15    105
# 2025-06-02    104
# 2025-06-13    103
# 2025-06-18    103
# 2025-06-05    101
# 2025-06-04    101
# 2025-06-25     99
# 2025-06-23     97
# 2025-06-24     97
# 2025-06-08     96
# 2025-06-22     96
# 2025-06-17     96
# 2025-06-11     95
# 2025-06-10     94
# 2025-06-20     93
# 2025-06-14     92
# 2025-06-06     91
# 2025-06-19     91
# 2025-06-03     89
# 2025-06-07     86
# 2025-06-12     85
# 2025-06-01     81
# 2025-06-09     81
# 2025-06-16     78
# Name: count, dtype: int64

# %% [markdown]
# D. MISSING VALUES

# %% [markdown]
# 30. Which columns in the dataset contain missing values, and how many missing values are in each?

# %%
display(df.isnull().sum())
# Out:
# test_date                            0
# device_name                          0
# brand                                0
# model                                0
# category                             0
# price_usd                            0
# battery_life_hours                   0
# heart_rate_accuracy_percent          0
# step_count_accuracy_percent          0
# sleep_tracking_accuracy_percent      0
# water_resistance_rating              0
# user_satisfaction_rating             0
# gps_accuracy_meters                632
# connectivity_features                0
# health_sensors_count                 0
# app_ecosystem_support                0
# performance_score                    0
# dtype: int64

# %% [markdown]
# 31. What is the total number of missing values in the GPS_Accuracy_Meters column?

# %%
display(df['gps_accuracy_meters'].isnull().sum())
# Out:
# np.int64(632)

# %% [markdown]
# 32. What percentage of values are missing in the GPS_Accuracy_Metrs column?

# %%
missing_gps_percentage = (df['gps_accuracy_meters'].isnull().sum() / len(df)) * 100
display(f"Percentage of missing values in GPS_Accuracy_Meters: {missing_gps_percentage:.2f}%")
# Out:
# 'Percentage of missing values in GPS_Accuracy_Meters: 26.61%'

# %% [markdown]
# 33. Using a heatmap, visualize missing values in the columns Device_Name, Brand, Model, Category, Water_Resistance_Rating, Connectivity_Features, and App_Ecosystem_Support. Provide the code used.

# %%
cols_to_visualize = ['device_name', 'brand', 'model', 'category', 'water_resistance_rating', 'connectivity_features', 'app_ecosystem_support']
plt.figure(figsize=(10, 6))
sns.heatmap(df[cols_to_visualize].isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values Heatmap for Categorical Columns')
plt.show()

# %% [markdown]
# 34. Using pandas, create a bar chart of missing values per column in the dataset. Provide the code and comment on the observations.

# %%
missing_values = df.isnull().sum()
missing_values = missing_values[missing_values > 0] # Filter to show only columns with missing values
if not missing_values.empty:
    missing_values.plot(kind='bar', figsize=(10, 6))
    plt.title('Missing Values Per Column')
    plt.xlabel('Columns')
    plt.ylabel('Number of Missing Values')
    plt.show()
else:
    display("No missing values found in the dataset.")

# Observation: The bar chart clearly shows that only the 'gps_accuracy_meters' column has missing values, with a count of 632.

# %% [markdown]
# 35. Using the missingno library, visualize the missing data pattern in the dataset. Provide the code and comment on the output.

# %%
import missingno as msno

msno.matrix(df)
plt.title('Missing Data Pattern')
plt.show()

# Observation: The missingno matrix shows that the 'gps_accuracy_meters' column is the only one with missing values, indicated by the white lines within that column. All other columns are complete.

# %% [markdown]
# 36. Suggest an approach for replacing missing values in the GPS_Accuracy_Meters column, and justify why this approach is appropriate.

# %% [markdown]
# For the 'gps_accuracy_meters' column, which has a notable number of missing values (26.61%), a suitable approach is to replace them with the median value of that column. This is appropriate because the median is less affected by potential outliers in the data compared to the mean, and it provides a central value for the missing data points.

# %% [markdown]
# 37. Replace missing values in the GPS_Accuracy_Meters column with the median value. Provide the code used.

# %%
median_gps_accuracy = df['gps_accuracy_meters'].median()
df['gps_accuracy_meters'].fillna(median_gps_accuracy, inplace=True)
# Out:
# /tmp/ipython-input-2784949135.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gps_accuracy_meters'].fillna(median_gps_accuracy, inplace=True)

# %% [markdown]
# 38. Suggest an approach for replacing missing values in the User_Satisfaction_Rating column, if any, and justify your choice.

# %%
# Based on the earlier analysis of missing values, the 'user_satisfaction_rating' column does not contain any missing values.
# Therefore, no imputation or replacement strategy is needed for this column.

# %% [markdown]
# 39. After replacing missing values in GPS_Accuracy_Meters, verify that there are no missing values left in this column. Provide the code used.

# %%
display(df['gps_accuracy_meters'].isnull().sum())
# Out:
# np.int64(0)

# %% [markdown]
# E. OUTLIER DETECTION AND HANDLING

# %% [markdown]
# 40. Using the IQR method, identify outliers in the Price_USD column. List the outlier values.

# %%
Q1 = df['price_usd'].quantile(0.25)
Q3 = df['price_usd'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_price_usd = df[(df['price_usd'] < lower_bound) | (df['price_usd'] > upper_bound)]['price_usd']
display("Outliers in Price_USD:")
display(outliers_price_usd)
# Out:
# 'Outliers in Price_USD:'
# 63      908.41
# 92      903.67
# 197     948.59
# 300     961.93
# 305     971.39
# 309     945.80
# 399     923.73
# 548     964.83
# 555     930.61
# 692     989.48
# 729     933.78
# 749     911.39
# 843     974.38
# 911     931.88
# 1074    956.74
# 1103    925.51
# 1181    919.95
# 1287    962.37
# 1317    934.12
# 1478    960.41
# 1521    928.79
# 1632    939.94
# 1713    977.73
# 1736    960.90
# 1925    914.20
# 1965    957.70
# 2006    962.55
# 2059    966.34
# 2152    971.28
# 2176    942.75
# 2187    933.02
# 2261    977.35
# 2358    917.50
# Name: price_usd, dtype: float64

# %% [markdown]
# 41. Using the IQR method, identify outliers in the Battery_Life_Hours  column. List the outlier values.

# %%
Q1 = df['battery_life_hours'].quantile(0.25)
Q3 = df['battery_life_hours'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_battery_life_hours = df[(df['battery_life_hours'] < lower_bound) | (df['battery_life_hours'] > upper_bound)]['battery_life_hours']
display("Outliers in Battery_Life_Hours:")
display(outliers_battery_life_hours)
# Out:
# 'Outliers in Battery_Life_Hours:'
# 7        589.9
# 17       459.6
# 25       644.7
# 29       512.5
# 33       537.9
#          ...
# 2288     461.8
# 2313     408.6
# 2358     612.8
# 2363     640.3
# 2366    2118.1
# Name: battery_life_hours, Length: 199, dtype: float64

# %% [markdown]
# 42. Using the IQR method, identify outliers in the Heart_Rate_Accuracy_Percent column. List the outlier values.

# %%
Q1 = df['heart_rate_accuracy_percent'].quantile(0.25)
Q3 = df['heart_rate_accuracy_percent'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_heart_rate = df[(df['heart_rate_accuracy_percent'] < lower_bound) | (df['heart_rate_accuracy_percent'] > upper_bound)]['heart_rate_accuracy_percent']
display("Outliers in Heart_Rate_Accuracy_Percent:")
display(outliers_heart_rate)
# Out:
# 'Outliers in Heart_Rate_Accuracy_Percent:'
# 58      86.20
# 91      85.39
# 101     85.32
# 123     85.97
# 139     85.42
#         ...
# 2272    85.65
# 2277    85.02
# 2279    85.27
# 2307    85.80
# 2322    86.08
# Name: heart_rate_accuracy_percent, Length: 87, dtype: float64

# %% [markdown]
# 43. Using the IQR method, identify outliers in the Step_Count_Accuracy_Percent column. List the outlier values.

# %%
Q1 = df['step_count_accuracy_percent'].quantile(0.25)
Q3 = df['step_count_accuracy_percent'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_step_count = df[(df['step_count_accuracy_percent'] < lower_bound) | (df['step_count_accuracy_percent'] > upper_bound)]['step_count_accuracy_percent']
display("Outliers in Step_Count_Accuracy_Percent:")
display(outliers_step_count)
# Out:
# 'Outliers in Step_Count_Accuracy_Percent:'
# Series([], Name: step_count_accuracy_percent, dtype: float64)

# %% [markdown]
# 44. Using the IQR method, identify outliers in the Sleep_Tracking_Accuracy_Percent column. List the outlier values.

# %%
Q1 = df['sleep_tracking_accuracy_percent'].quantile(0.25)
Q3 = df['sleep_tracking_accuracy_percent'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_sleep_tracking = df[(df['sleep_tracking_accuracy_percent'] < lower_bound) | (df['sleep_tracking_accuracy_percent'] > upper_bound)]['sleep_tracking_accuracy_percent']
display("Outliers in Sleep_Tracking_Accuracy_Percent:")
display(outliers_sleep_tracking)
# Out:
# 'Outliers in Sleep_Tracking_Accuracy_Percent:'
# 24      91.48
# 398     91.73
# 589     91.60
# 609     91.71
# 654     91.97
# 688     91.93
# 761     91.60
# 919     91.97
# 1116    91.64
# 1404    91.48
# 1421    91.73
# 1449    91.94
# 1573    91.84
# 1582    91.60
# 1684    91.48
# 1692    91.56
# 1865    91.95
# 2048    91.66
# 2072    91.79
# 2116    91.80
# 2265    91.89
# Name: sleep_tracking_accuracy_percent, dtype: float64

# %% [markdown]
# 45.Using the IQR method, identify outliers in the Performance_Score column. List the outlier values.

# %%
Q1 = df['performance_score'].quantile(0.25)
Q3 = df['performance_score'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_performance_score = df[(df['performance_score'] < lower_bound) | (df['performance_score'] > upper_bound)]['performance_score']
display("Outliers in Performance_Score:")
display(outliers_performance_score)
# Out:
# 'Outliers in Performance_Score:'
# Series([], Name: performance_score, dtype: float64)

# %% [markdown]
# 46. Provide the code to remove outliers from all numerical columns using the IQR method.

# %%
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

for col in numerical_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df = df[(df[col] >= lower_bound) & (df[col] <= upper_bound)]

# %% [markdown]
# 47. What is the sample size of the dataset after removing outliers from all numerical columns?

# %%
display(f"Sample size after removing outliers: {df.shape[0]}")
# Out:
# 'Sample size after removing outliers: 2125'

# %% [markdown]
# 48. Create boxplots for all numerical columns before removing outliers. Provide the code used.

# %%
# Reload the original dataset
df_original = pd.read_csv('/content/wearable_health_devices_performance_upto_26june2025.csv')

numerical_cols = df_original.select_dtypes(include=np.number).columns.tolist()

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(3, 3, i + 1)
    sns.boxplot(x=df_original[col])
    plt.title(f'Boxplot of {col} (Before Outlier Removal)')
plt.tight_layout()
plt.show()

# %% [markdown]
# 49. Create boxplots for all numerical columns after removing outliers. Provide the code used and comment on the differences

# %%
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols):
    plt.subplot(3, 3, i + 1)
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col} (After Outlier Removal)')
plt.tight_layout()
plt.show()

# %% [markdown]
# F. VISUALIZATION

# %% [markdown]
# 50. Create a histogram for Price_USD with 50 bins and a KDE curve. Provide the code used

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['price_usd'], bins=50, kde=True)
plt.title('Distribution of Price_USD')
plt.xlabel('Price (USD)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 51. Create a histogram for Battery_Life_Hours with 50 bins and a KDE curve. Provide the code used

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['battery_life_hours'], bins=50, kde=True)
plt.title('Distribution of Battery_Life_Hours')
plt.xlabel('Battery Life (Hours)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 52. Create a histogram for Heart_Rate_Accuracy_Percent with 50 bins and a KDE curve. Provide the code used

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['heart_rate_accuracy_percent'], bins=50, kde=True)
plt.title('Distribution of Heart_Rate_Accuracy_Percent')
plt.xlabel('Heart Rate Accuracy (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 53. Create a histogram for Step_Count_Accuracy_Percent with 50 bins and a KDE curve. Provide the code used

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['step_count_accuracy_percent'], bins=50, kde=True)
plt.title('Distribution of Step_Count_Accuracy_Percent')
plt.xlabel('Step Count Accuracy (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 54. Create a histogram for Sleep_Tracking_Accuracy_Percent with 50 bins and a KDE curve. Provide the code used

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['sleep_tracking_accuracy_percent'], bins=50, kde=True)
plt.title('Distribution of Sleep_Tracking_Accuracy_Percent')
plt.xlabel('Sleep Tracking Accuracy (%)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 55. Create a bar plot showing the average User_Satisfaction_Rating by Category. Provide the code used.

# %%
avg_satisfaction_by_category = df.groupby('category')['user_satisfaction_rating'].mean().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
sns.barplot(x=avg_satisfaction_by_category.index, y=avg_satisfaction_by_category.values)
plt.title('Average User Satisfaction Rating by Category')
plt.xlabel('Category')
plt.ylabel('Average User Satisfaction Rating')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 56. Create a bar plot showing the average Performance_Score by Brand. Provide the code used.

# %%
avg_performance_by_brand = df.groupby('brand')['performance_score'].mean().sort_values(ascending=False)

plt.figure(figsize=(12, 6))
sns.barplot(x=avg_performance_by_brand.index, y=avg_performance_by_brand.values)
plt.title('Average Performance Score by Brand')
plt.xlabel('Brand')
plt.ylabel('Average Performance Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 57. Create a box plot showing the distribution of Price_USD by Category. Provide the code used.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='category', y='price_usd', data=df)
plt.title('Distribution of Price_USD by Category')
plt.xlabel('Category')
plt.ylabel('Price (USD)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 58. Create a box plot showing the distribution of Battery_Life_Hours by Brand. Provide the code used.

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='brand', y='battery_life_hours', data=df)
plt.title('Distribution of Battery_Life_Hours by Brand')
plt.xlabel('Brand')
plt.ylabel('Battery Life (Hours)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# 59. Create a scatter plot of Heart_Rate_Accuracy_Percent vs. Step_Count_Accuracy_Percent, colored by Category. Provide the code used.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='heart_rate_accuracy_percent', y='step_count_accuracy_percent', hue='category', data=df)
plt.title('Heart Rate Accuracy vs. Step Count Accuracy by Category')
plt.xlabel('Heart Rate Accuracy (%)')
plt.ylabel('Step Count Accuracy (%)')
plt.show()

# %% [markdown]
# G. CORRELATION ANALYSIS

# %% [markdown]
# Create a correlation heatmap for all numerical columns with annotations. Provide the code used

# %%
numerical_cols = df.select_dtypes(include=np.number).columns
correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Numerical Columns')
plt.show()

# %% [markdown]
# 60. Create a lower triangle correlation heatmap for numerical columns. Provide the code used.

# %%
numerical_cols = df.select_dtypes(include=np.number).columns
correlation_matrix = df[numerical_cols].corr()

# Create a mask for the upper triangle
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool))

plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", mask=mask)
plt.title('Lower Triangle Correlation Heatmap of Numerical Columns')
plt.show()

# %% [markdown]
# 61. What is the correlation coefficient between Heart_Rate_Accuracy_Percent and Step_Count_Accuracy_Percent?

# %%
correlation = correlation_matrix.loc['heart_rate_accuracy_percent', 'step_count_accuracy_percent']
display(f"Correlation coefficient between Heart_Rate_Accuracy_Percent and Step_Count_Accuracy_Percent: {correlation:.2f}")
# Out:
# 'Correlation coefficient between Heart_Rate_Accuracy_Percent and Step_Count_Accuracy_Percent: 0.22'

# %% [markdown]
# 62. What is the correlation coefficient between Price_USD and Performance_Score?

# %%
correlation = correlation_matrix.loc['price_usd', 'performance_score']
display(f"Correlation coefficient between Price_USD and Performance_Score: {correlation:.2f}")
# Out:
# 'Correlation coefficient between Price_USD and Performance_Score: -0.10'

# %% [markdown]
# 63. What is the correlation coefficient between Battery_Life_Hours and User_Satisfaction_Rating?

# %%
correlation = correlation_matrix.loc['battery_life_hours', 'user_satisfaction_rating']
display(f"Correlation coefficient between Battery_Life_Hours and User_Satisfaction_Rating: {correlation:.2f}")
# Out:
# 'Correlation coefficient between Battery_Life_Hours and User_Satisfaction_Rating: -0.15'

# %% [markdown]
# 64. Create a pairplot for numerical columns (Price_USD, Battery_Life_Hours, Heart_Rate_Accuracy_Percent, Step_Count_Accuracy_Percent, Performance_Score), colored by Category. Provide the code used.

# %%
numerical_cols_for_pairplot = ['price_usd', 'battery_life_hours', 'heart_rate_accuracy_percent', 'step_count_accuracy_percent', 'performance_score']
sns.pairplot(df[numerical_cols_for_pairplot + ['category']], hue='category')
plt.suptitle('Pairplot of Numerical Columns by Category', y=1.02)
plt.show()

# %% [markdown]
# 65. Which numerical features have the highest positive correlation with Perfomance_Score?

# %%
performance_correlation = correlation_matrix['performance_score'].sort_values(ascending=False)
display("Numerical features with the highest positive correlation with Performance_Score:")
display(performance_correlation.drop('performance_score').head()) # Drop self-correlation and display top positive correlations
# Out:
# 'Numerical features with the highest positive correlation with Performance_Score:'
# battery_life_hours                 0.566388
# sleep_tracking_accuracy_percent    0.339228
# user_satisfaction_rating           0.084855
# price_usd                         -0.095133
# gps_accuracy_meters               -0.134684
# Name: performance_score, dtype: float64

# %% [markdown]
# 66. Which numerical features have the highest negative correlation with User_Satisfaction_Rating?

# %%
user_satisfaction_correlation = correlation_matrix['user_satisfaction_rating'].sort_values(ascending=True)
display("Numerical features with the highest negative correlation with User_Satisfaction_Rating:")
display(user_satisfaction_correlation.drop('user_satisfaction_rating').head()) # Drop self-correlation and display top negative correlations
# Out:
# 'Numerical features with the highest negative correlation with User_Satisfaction_Rating:'
# battery_life_hours            -0.146851
# gps_accuracy_meters           -0.016222
# performance_score              0.084855
# heart_rate_accuracy_percent    0.185913
# step_count_accuracy_percent    0.195186
# Name: user_satisfaction_rating, dtype: float64

# %% [markdown]
# 67. Create a scatter plot of Price_USD vs. Performance_Score with a regression line. Provide the code used.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='price_usd', y='performance_score', data=df)
plt.title('Price_USD vs. Performance_Score with Regression Line')
plt.xlabel('Price (USD)')
plt.ylabel('Performance Score')
plt.show()

# %% [markdown]
# 68. Create a scatter plot of Battery_Life_Hours vs. User_Satisfaction_Rating with a regression line. Provide the code used.

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='battery_life_hours', y='user_satisfaction_rating', data=df)
plt.title('Battery_Life_Hours vs. User_Satisfaction_Rating with Regression Line')
plt.xlabel('Battery Life (Hours)')
plt.ylabel('User Satisfaction Rating')
plt.show()

# %% [markdown]
# H. GROUPING AND AGGREGATION

# %% [markdown]
# 69. What is the average Price_USD for each Category?

# %%
average_price_by_category = df.groupby('category')['price_usd'].mean()
display(average_price_by_category)
# Out:
# category
# Fitness Band        30.000000
# Fitness Tracker    197.510294
# Smart Ring         429.170521
# Smartwatch         412.809716
# Sports Watch       305.615707
# Name: price_usd, dtype: float64

# %% [markdown]
# 70. What is the average Battery_Life_Hours for each Brand?

# %%
average_battery_life_by_brand = df.groupby('brand')['battery_life_hours'].mean()
display(average_battery_life_by_brand)
# Out:
# brand
# Amazfit     110.722845
# Apple        44.001946
# Fitbit      132.640084
# Garmin      302.616667
# Huawei       46.591220
# Oura        179.859716
# Polar        93.729796
# Samsung      44.885171
# WHOOP       143.840670
# Withings    104.575943
# Name: battery_life_hours, dtype: float64

# %% [markdown]
# 71. What is the average User_Satisfaction_Rating for each Water_Resistance_Rating?

# %%
average_satisfaction_by_water_resistance = df.groupby('water_resistance_rating')['user_satisfaction_rating'].mean()
display(average_satisfaction_by_water_resistance)
# Out:
# water_resistance_rating
# 10ATM    7.850000
# 3ATM     7.251351
# 5ATM     8.046200
# IP68     8.094497
# IPX4     7.191333
# IPX7     7.748523
# IPX8     8.058361
# Name: user_satisfaction_rating, dtype: float64

# %% [markdown]
# 72. What is the maximum Performance_Score for each App_Ecosystem_Support category?

# %%
max_performance_by_ecosystem = df.groupby('app_ecosystem_support')['performance_score'].max()
display(max_performance_by_ecosystem)
# Out:
# app_ecosystem_support
# Android/iOS       78.0
# Cross-platform    78.3
# iOS               64.4
# Name: performance_score, dtype: float64

# %% [markdown]
# 73. What is the minmum Heart_Rate_Accuracy_Percent for each Category?

# %%
minimum_heart_rate_by_category = df.groupby('category')['heart_rate_accuracy_percent'].min()
display(minimum_heart_rate_by_category)
# Out:
# category
# Fitness Band       85.65
# Fitness Tracker    88.02
# Smart Ring         85.71
# Smartwatch         92.01
# Sports Watch       92.03
# Name: heart_rate_accuracy_percent, dtype: float64

# %% [markdown]
# 74. Group the dataset by Brand and calculate the mean Step_Count_Accuracy_Percent.

# %%
median_sleep_accuracy_by_category = df.groupby('category')['sleep_tracking_accuracy_percent'].median()
display(median_sleep_accuracy_by_category)
# Out:
# category
# Fitness Band       75.13
# Fitness Tracker    75.46
# Smart Ring         88.48
# Smartwatch         79.77
# Sports Watch       74.89
# Name: sleep_tracking_accuracy_percent, dtype: float64

# %% [markdown]
# 75. Group the dataset by Category and calculate the median Step_Tracking_Accuracy_Percent.

# %%
median_step_accuracy_by_category = df.groupby('category')['step_count_accuracy_percent'].median()
display(median_step_accuracy_by_category)
# Out:
# category
# Fitness Band       95.140
# Fitness Tracker    95.230
# Smart Ring         94.730
# Smartwatch         96.380
# Sports Watch       95.265
# Name: step_count_accuracy_percent, dtype: float64

# %% [markdown]
# 76. Group the dataset by Connectivity_Features and calculate the total count of devices.

# %%
device_count_by_connectivity = df.groupby('connectivity_features').size()
display(device_count_by_connectivity)
# Out:
# connectivity_features
# Bluetooth                    801
# Bluetooth, WiFi              199
# WiFi, Bluetooth, NFC         562
# WiFi, Bluetooth, NFC, LTE    563
# dtype: int64

# %% [markdown]
# 77. Group the dataset by App_Ecosystem_Support and calculate the average Price_USD.

# %%
average_price_by_ecosystem = df.groupby('app_ecosystem_support')['price_usd'].mean()
display(average_price_by_ecosystem)
# Out:
# app_ecosystem_support
# Android/iOS       339.368144
# Cross-platform    294.054786
# iOS               525.029494
# Name: price_usd, dtype: float64

# %% [markdown]
# 78. Group the dataset by Water_Resistance_Rating and calculate the standard deviation of Battery_Life_Hours.

# %%
std_battery_life_by_water_resistance = df.groupby('water_resistance_rating')['battery_life_hours'].std()
display(std_battery_life_by_water_resistance)
# Out:
# water_resistance_rating
# 10ATM    13.081475
# 3ATM     34.565689
# 5ATM     72.076719
# IP68     64.906058
# IPX4     33.899744
# IPX7     28.702261
# IPX8     73.325829
# Name: battery_life_hours, dtype: float64

# %% [markdown]
# 79. How would you check for duplicate rows in the dataset? Provide the code.

# %%
display(df.duplicated().sum())
# Out:
# np.int64(0)

# %% [markdown]
# 80. Remove duplicate rows from the dataset, if any, and report the number of duplicates removed. Provide the code used.

# %%
initial_rows = df.shape[0]
df.drop_duplicates(inplace=True)
rows_after_dropping_duplicates = df.shape[0]
duplicates_removed = initial_rows - rows_after_dropping_duplicates

display(f"Number of duplicate rows removed: {duplicates_removed}")
# Out:
# 'Number of duplicate rows removed: 0'

# %% [markdown]
# I. ADVANCED ANALYSIS

# %% [markdown]
# 81. What is the average Performance_Score for devices with Water_Resistance_Rating of 5ATM?

# %%
average_performance_5atm = df[df['water_resistance_rating'] == '5ATM']['performance_score'].mean()
display(f"Average Performance_Score for devices with Water_Resistance_Rating of 5ATM: {average_performance_5atm:.2f}")
# Out:
# 'Average Performance_Score for devices with Water_Resistance_Rating of 5ATM: 60.96'

# %% [markdown]
# 82. What is the average User_Satisfaction_Rating for devices with Connectivity_Features including Bluetooth?

# %%
average_satisfaction_bluetooth = df[df['connectivity_features'].str.contains('Bluetooth')]['user_satisfaction_rating'].mean()
display(f"Average User_Satisfaction_Rating for devices with Connectivity_Features including Bluetooth: {average_satisfaction_bluetooth:.2f}")
# Out:
# 'Average User_Satisfaction_Rating for devices with Connectivity_Features including Bluetooth: 7.93'

# %% [markdown]
# 83. Which Brand has the highest average Heart_Rate_Accuracy_Percent?

# %%
average_heart_rate_by_brand = df.groupby('brand')['heart_rate_accuracy_percent'].mean()
brand_highest_avg_heart_rate = average_heart_rate_by_brand.idxmax()
display(f"The Brand with the highest average Heart_Rate_Accuracy_Percent is: {brand_highest_avg_heart_rate}")
# Out:
# 'The Brand with the highest average Heart_Rate_Accuracy_Percent is: Withings'

# %% [markdown]
# 84. Which Category has the lowest average Price_USD?

# %%
lowest_average_price_category = average_price_by_category.idxmin()
display(f"The Category with the lowest average Price_USD is: {lowest_average_price_category}")
# Out:
# 'The Category with the lowest average Price_USD is: Fitness Band'

# %% [markdown]
# 85. Create a pivot table showing the average Performance_Score by Brand and Category, Provide the code used?

# %%
pivot_table_performance = df.pivot_table(values='performance_score', index='brand', columns='category', aggfunc='mean')
display(pivot_table_performance)
# Out:
# category  Fitness Band  Fitness Tracker  Smart Ring  Smartwatch  Sports Watch
# brand
# Amazfit            NaN        70.264815         NaN   59.357647     60.109677
# Apple              NaN              NaN         NaN   61.366926           NaN
# Fitbit             NaN        70.634483         NaN   59.327586     60.344444
# Garmin             NaN              NaN         NaN   63.788000     63.475862
# Huawei             NaN              NaN         NaN   60.827805           NaN
# Oura               NaN              NaN   75.063981         NaN           NaN
# Polar              NaN              NaN         NaN   60.434586     61.521429
# Samsung            NaN              NaN         NaN   61.374905           NaN
# WHOOP         69.14067              NaN         NaN         NaN           NaN
# Withings           NaN              NaN         NaN   60.603030     61.489381

# %% [markdown]
# 86. Create a pivot table showing the count of devices by Water_Resistance_Rating and App_Ecosystem_Support. Provide the code used.

# %%
pivot_table_count = df.pivot_table(index='water_resistance_rating', columns='app_ecosystem_support', aggfunc='size', fill_value=0)
display(pivot_table_count)
# Out:
# app_ecosystem_support    Android/iOS  Cross-platform  iOS
# water_resistance_rating
# 10ATM                              0               2    0
# 3ATM                              36              75    0
# 5ATM                             167             243   90
# IP68                             192             243   92
# IPX4                              58              92    0
# IPX7                              96             141    0
# IPX8                             243             280   75

# %% [markdown]
# 87. What is the average GPS_Accuracy_Meters for devices with Health_Sensors_Count greater than 8?

# %%
average_gps_high_sensors = df[df['health_sensors_count'] > 8]['gps_accuracy_meters'].mean()
display(f"Average GPS_Accuracy_Meters for devices with Health_Sensors_Count > 8: {average_gps_high_sensors:.2f}")
# Out:
# 'Average GPS_Accuracy_Meters for devices with Health_Sensors_Count > 8: 3.24'

# %% [markdown]
# 88. How many devices have a User_Satisfaction_Rating above 9.0?

# %%
devices_above_9 = df[df['user_satisfaction_rating'] > 9.0].shape[0]
display(f"Number of devices with User_Satisfaction_Rating above 9.0: {devices_above_9}")
# Out:
# 'Number of devices with User_Satisfaction_Rating above 9.0: 238'

# %% [markdown]
# 89. What is the distribution of Health_Sensors_Count across all devices? Create a histogram to visualize it.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['health_sensors_count'], bins=10, kde=False) # Using bins=10 as it's count data
plt.title('Distribution of Health_Sensors_Count')
plt.xlabel('Number of Health Sensors')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 90. Creating a violin plot showing the distribution of Performance_Score by Category. Provide the code used.

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(x='category', y='performance_score', data=df)
plt.title('Distribution of Performance_Score by Category')
plt.xlabel('Category')
plt.ylabel('Performance Score')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
